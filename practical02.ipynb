# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.2

# %%
x=pd.DataFrame({'Rollno':[101,102,103],'Name':['rahul','pranit','seema']})

# %%
x
# Out:
#    Rollno    Name
# 0     101   rahul
# 1     102  pranit
# 2     103   seema

# %%
df.subscribe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.subscribe
#
# NameError: name 'df' is not defined
