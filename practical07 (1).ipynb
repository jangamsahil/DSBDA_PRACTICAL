# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.9.4)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
import pandas as pd
import math
import re
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt') 
nltk.download('stopwords') 
nltk.download('wordnet') 
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')   # ✅ THIS is the missing one
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text="Tokenization is the first step in text analytics.The process of breaking down a text paragraph into smaller chunks such as words or sentences is called Tokenization."

# %%
from nltk.tokenize import sent_tokenize

tokenized_text = sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Tokenization is the first step in text analytics.The process of breaking down a text paragraph into smaller chunks such as words or sentences is called Tokenization.']

# %%
# Step 3: Word Tokenization
from nltk.tokenize import word_tokenize

tokenized_word = word_tokenize(text)
print("\nWord Tokenization:")
print(tokenized_word)
# Out:
# Word Tokenization:
# ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics.The', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'Tokenization', '.']

# %%
# Step 4: Removing Punctuations and Stop Words
from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))
print("\nStop Words:")
print(stop_words)

# Remove punctuation
clean_text = re.sub('[^a-zA-Z]', ' ', text)

tokens = word_tokenize(clean_text.lower())

filtered_text = []
for w in tokens:
    if w not in stop_words:
        filtered_text.append(w)

print("\nTokenized Sentence:", tokens)
print("Filtered Sentence:", filtered_text)
# Out:
# Stop Words:
# {"you'll", 'it', 'during', "she'll", 'such', 'that', 'when', 'doesn', "should've", 'some', "they'd", 'wasn', 'on', 'over', 'does', 'of', 'herself', "it's", 'should', "you'd", 'd', 'as', 'our', 'you', "i'd", 'whom', 'yourself', "they'll", 'through', 'has', 'her', 'hadn', 'i', 'ours', 'both', 'me', "didn't", 'what', 'a', 'to', 'or', 'mustn', "won't", "couldn't", 'won', "hasn't", 'and', 'yours', 'couldn', 'which', 'why', "we'll", 'down', 'below', 'by', 'nor', 'the', 'doing', 'have', 'is', "wasn't", "she'd", "wouldn't", 'with', 'out', "they're", 'how', 'shan', 'ma', 'yourselves', 'again', 'then', 'being', 'we', 'no', "we've", 'at', 'for', 'theirs', "aren't", 'hers', 'most', "it'll", 'above', 'because', "don't", "i'll", 'itself', "she's", 'few', 'once', 'y', 'up', "isn't", 'she', 'just', "i'm", 'more', 'o', 'been', "doesn't", "needn't", 'your', 'but', 'are', 'shouldn', 'not', 'in', 'after', 'further', 'these', 'wouldn', 'all', 'where', 'off', 'haven', "we're", 'him', 'his', 'am', 'under', 'them', 'there', 'about', "mightn't", 't', 'before', 've', 'be', 'can', "shouldn't", 'didn', "he's", 'll', 'their', 'this', 'now', 'an', "haven't", "they've", 'its', "shan't", 'only', 'who', 'so', 'here', 'while', 'isn', 'having', 'needn', 'he', 'those', 'too', "he'd", 'until', 'themselves', 'ain', 'weren', 'if', 'from', "i've", 'was', "that'll", 'between', 'myself', 'did', "hadn't", 'own', "weren't", 'into', 'hasn', "you're", 'than', 'mightn', 'other', 'against', 're', 'any', "it'd", 'will', 'm', 'very', 'do', 'don', 'himself', 'had', 'my', 'they', "we'd", 'ourselves', "you've", 'were', 's', "he'll", 'same', 'aren', 'each', "mustn't"}
#
# Tokenized Sentence: ['tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', 'the', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'tokenization']
# Filtered Sentence: ['tokenization', 'first', 'step', 'text', 'analytics', 'process', 'breaking', 'text', 'paragraph', 'smaller', 'chunks', 'words', 'sentences', 'called', 'tokenization']

# %%
# Step 5: Stemming
from nltk.stem import PorterStemmer

ps = PorterStemmer()
e_words = ["wait", "waiting", "waited", "waits"]

print("\nStemming:")
for w in e_words:
    rootWord = ps.stem(w)
    print(w, "->", rootWord)
# Out:
# Stemming:
# wait -> wait
# waiting -> wait
# waited -> wait
# waits -> wait

# %%
# Step 6: Lemmatization
from nltk.stem import WordNetLemmatizer

wordnet_lemmatizer = WordNetLemmatizer()

text2 = "studies studying cries cry"
tokens2 = word_tokenize(text2)

print("\nLemmatization:")
for w in tokens2:
    print(f"{w} -> {wordnet_lemmatizer.lemmatize(w)}")
# Out:
# Lemmatization:
# studies -> study
# studying -> studying
# cries -> cry
# cry -> cry

# %%
# Step 7: POS Tagging
from nltk.tokenize import word_tokenize

data = "The pink sweater fit her perfectly"
words = word_tokenize(data)

print("\nPOS Tagging:")
for word in words:
    print(nltk.pos_tag([word]))
# Out:
# POS Tagging:
# [('The', 'DT')]
# [('pink', 'NN')]
# [('sweater', 'NN')]
# [('fit', 'NN')]
# [('her', 'PRP$')]
# [('perfectly', 'RB')]

# %%
# Step 1: Import necessary libraries
import pandas as pd
import math

# %%
# Step 2: Initialize Documents
documentA = 'Jupiter is the largest planet'
documentB = 'Mars is the fourth planet from the sun'

# %%
# Step 3: Create Bag of Words (BoW)
bagOfWordsA = documentA.split(' ')
bagOfWordsB = documentB.split(' ')

# %%
# Step 4: Create collection of unique words
uniqueWords = set(bagOfWordsA).union(set(bagOfWordsB))

# %%
# Step 5: Create word count dictionary for each document

numOfWordsA = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsA:
    numOfWordsA[word] += 1

numOfWordsB = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsB:
    numOfWordsB[word] += 1

# %%
# Step 6: Compute Term Frequency (TF)

def computeTF(wordDict, bagOfWords):
    tfDict = {}
    bagOfWordsCount = len(bagOfWords)
    
    for word, count in wordDict.items():
        tfDict[word] = count / float(bagOfWordsCount)
        
    return tfDict

tfA = computeTF(numOfWordsA, bagOfWordsA)
tfB = computeTF(numOfWordsB, bagOfWordsB)

# %%
idfs = computeIDF([numOfWordsA, numOfWordsB])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 idfs = computeIDF([numOfWordsA, numOfWordsB])
#
# NameError: name 'computeIDF' is not defined

# %%
# Step 8: Compute TF-IDF

def computeTFIDF(tfBagOfWords, idfs):
    tfidf = {}
    
    for word, val in tfBagOfWords.items():
        tfidf[word] = val * idfs[word]
    
    return tfidf

tfidfA = computeTFIDF(tfA, idfs)
tfidfB = computeTFIDF(tfB, idfs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 11
#       7         tfidf[word] = val * idfs[word]
#       9     return tfidf
# ---> 11 tfidfA = computeTFIDF(tfA, idfs)
#      12 tfidfB = computeTFIDF(tfB, idfs)
#
# NameError: name 'idfs' is not defined
