# %% [markdown]
# Assignment no : 4

# %% [markdown]
# Roll No : 13215  Name: Sahil Jangam

# %% [markdown]
# Problem Statement:1.Creation of Dataset using Microsoft Excel.
# 2.Identification and Handling of Outliers 3.Data Transformation for the purpose of : a. To change the scale for better understanding b. To decrease the skewness and convert distribution into normal distribution

# %%
import pandas as pd;

# %%
df=pd.read_csv("C:/Users/HP/OneDrive/Desktop/stud_performance.csv");

# %%
df
# Out:
#     math-score  reading_score  writing_score  placement_score  club_join_year  \
# 0         60.0           92.0           65.0             98.0          2020.0
# 1         63.0           84.0           67.0             92.0          2019.0
# 2         76.0           79.0           60.0             87.0          2021.0
# 3         79.0           81.0           70.0            100.0          2018.0
# 4         72.0           77.0           64.0            100.0          2019.0
# 5         64.0           83.0           71.0             84.0          2020.0
# 6          NaN           80.0           75.0             90.0          2020.0
# 7         63.0           82.0           76.0             99.0          2018.0
# 8         63.0           83.0           76.0             92.0          2018.0
# 9         60.0           84.0           74.0             90.0          2018.0
# 10         NaN            NaN           79.0             76.0          2019.0
# ...

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   math-score       46 non-null     float64
#  1   reading_score    47 non-null     float64
#  2   writing_score    46 non-null     float64
#  3   placement_score  46 non-null     float64
#  4   club_join_year   46 non-null     float64
#  5   placement_offer  46 non-null     float64
# dtypes: float64(6)
# memory usage: 2.4 KB

# %%
df.describe()
# Out:
#        math-score  reading_score  writing_score  placement_score  \
# count   46.000000      47.000000      46.000000        46.000000
# mean    73.413043      86.893617      73.739130        87.934783
# std     20.095965      18.142233      19.862231         7.549546
# min     60.000000      75.000000      60.000000        75.000000
# 25%     64.250000      78.000000      67.000000        81.250000
# 50%     70.500000      84.000000      71.000000        88.500000
# 75%     77.000000      91.500000      76.000000        93.500000
# max    200.000000     200.000000     200.000000       100.000000
#
#        club_join_year  placement_offer
# count       46.000000        46.000000
# mean      2019.673913         2.630435
# std          1.174816         0.571886
# min       2018.000000         1.000000
# 25%       2019.000000         2.000000
# 50%       2019.500000         3.000000
# 75%       2021.000000         3.000000
# max       2021.000000         3.000000

# %%
df.isnull().sum()
# Out:
# math-score         3
# reading_score      2
# writing_score      3
# placement_score    3
# club_join_year     3
# placement_offer    3
# dtype: int64

# %%
df.rename(columns={'math-score': 'math_score'}, inplace=True)

# %%
x=df.math_score.mean()

# %%
df.math_score.fillna(x, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2252\629572127.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.math_score.fillna(x, inplace=True)

# %%
y=df.reading_score.mean()

# %%
df.reading_score.fillna(y,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2252\4092209863.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.reading_score.fillna(y,inplace=True)

# %%
z=df.writing_score.mean()

# %%
df.writing_score.fillna(z,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2252\1043828731.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.writing_score.fillna(z,inplace=True)

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0    60.000000      92.000000       65.00000             98.0          2020.0
# 1    63.000000      84.000000       67.00000             92.0          2019.0
# 2    76.000000      79.000000       60.00000             87.0          2021.0
# 3    79.000000      81.000000       70.00000            100.0          2018.0
# 4    72.000000      77.000000       64.00000            100.0          2019.0
# 5    64.000000      83.000000       71.00000             84.0          2020.0
# 6    73.413043      80.000000       75.00000             90.0          2020.0
# 7    63.000000      82.000000       76.00000             99.0          2018.0
# 8    63.000000      83.000000       76.00000             92.0          2018.0
# 9    60.000000      84.000000       74.00000             90.0          2018.0
# 10   73.413043      86.893617       79.00000             76.0          2019.0
# ...

# %%
df.placement_score.fillna(222,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2252\1146741468.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.placement_score.fillna(222,inplace=True)

# %%
df.club_join_year.fillna(2019 , inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2252\2724723784.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.club_join_year.fillna(2019 , inplace=True)

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0    60.000000      92.000000       65.00000             98.0          2020.0
# 1    63.000000      84.000000       67.00000             92.0          2019.0
# 2    76.000000      79.000000       60.00000             87.0          2021.0
# 3    79.000000      81.000000       70.00000            100.0          2018.0
# 4    72.000000      77.000000       64.00000            100.0          2019.0
# 5    64.000000      83.000000       71.00000             84.0          2020.0
# 6    73.413043      80.000000       75.00000             90.0          2020.0
# 7    63.000000      82.000000       76.00000             99.0          2018.0
# 8    63.000000      83.000000       76.00000             92.0          2018.0
# 9    60.000000      84.000000       74.00000             90.0          2018.0
# 10   73.413043      86.893617       79.00000             76.0          2019.0
# ...

# %%
df.placement_offer.fillna(10, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2252\472989215.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.placement_offer.fillna(10, inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['math_score', 'reading_score', 'writing_score', 'placement_score',
#        'club_join_year', 'placement_offer'],
#       dtype='object')

# %%
col=['math_score', 'reading_score', 'writing_score', 'placement_score',
       'club_join_year', 'placement_offer']

# %%
df.boxplot(col)
# Out:
# <Axes: >

# %%
col1=['math_score', 'reading_score', 'writing_score', 'placement_score']

# %%
df.boxplot(col1)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
plt.scatterplot(placement_score,place_offer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 plt.scatterplot(placement_score,place_offer)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'scatterplot'

# %%
fix, ax = plt.subplots(figsize = (18, 10))

# %%
ax.scatter(df['placement_score'],df['placement_offer'])

# %%
plt.show()

# %%
q1 = np.percentile(df.placement_offer ,25)

# %%
import numpy as np

# %%
q1
# Out:
# np.float64(2.0)

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score  placement_score  \
# count   49.000000      49.000000      49.000000        49.000000
# mean    73.413043      86.893617      73.739130        96.142857
# std     19.457835      17.760248      19.231522        33.286634
# min     60.000000      75.000000      60.000000        75.000000
# 25%     65.000000      78.000000      67.000000        82.000000
# 50%     72.000000      84.000000      73.000000        89.000000
# 75%     77.000000      91.000000      76.000000        95.000000
# max    200.000000     200.000000     200.000000       222.000000
#
#        club_join_year  placement_offer
# count       49.000000        49.000000
# mean      2019.632653         3.081633
# std          1.149164         1.869010
# min       2018.000000         1.000000
# 25%       2019.000000         2.000000
# 50%       2019.000000         3.000000
# 75%       2021.000000         3.000000
# max       2021.000000        10.000000

# %%
q3 = np.percentile(df.placement_offer , 75)

# %%
IQR = q3 - q1

# %%
IQR
# Out:
# np.float64(1.0)

# %%
upper_bod= q3 + 1.5*IQR

# %%
upper_bod
# Out:
# np.float64(4.5)

# %%
lower_bod = q1- 1.5*IQR

# %%
lower_bod
# Out:
# np.float64(0.5)

# %%
from scipy import stats

# %%
s = np.abs(stats.zscore(df['placement_offer']))

# %%
s
# Out:
# array([0.04412958, 0.04412958, 0.04412958, 0.04412958, 0.04412958,
#        0.58471691, 0.04412958, 0.04412958, 0.04412958, 0.04412958,
#        0.58471691, 0.04412958, 3.73998175, 3.73998175, 0.04412958,
#        1.12530424, 3.73998175, 0.04412958, 1.12530424, 0.04412958,
#        0.58471691, 0.04412958, 0.04412958, 0.58471691, 0.58471691,
#        0.04412958, 0.04412958, 0.04412958, 0.04412958, 0.58471691,
#        0.58471691, 0.58471691, 0.04412958, 0.04412958, 0.58471691,
#        0.04412958, 0.04412958, 0.04412958, 0.04412958, 0.58471691,
#        0.58471691, 0.58471691, 0.04412958, 0.04412958, 0.04412958,
#        0.58471691, 0.04412958, 0.04412958, 0.04412958])
